# %%
import seaborn as sns

# %%
import numpy as np
np.random.seed(123)
data=np.random.randn(10000)
# data

# %%
data.mean()
# Out:
# 0.009711892291595955

# %%
data.std()
# Out:
# 0.9981138545901473

# %%
data.min()
# Out:
# -3.801378196860991

# %%
data.max()
# Out:
# 4.068096914834083

# %%
sns.distplot(data)

# %%
# 期望值μ=0，即曲线图象对称轴为Y轴，标准差σ=1条件下的正态分布，记为N(0，1)。

# %%
# b、服从μ=loc,σ=scale 的正态分布：
data2=np.random.normal(loc=2, scale=1, size=10000)
data2
# Out:
# array([3.91224988, 1.73172857, 1.22065083, ..., 1.57633149, 0.92476475,
#        0.51338573])

# %%
sns.distplot(data2)
